# %%
import numpy as np
import matplotlib.pyplot as plt
import random


import importlib
#--------------------import class indirectly so itt reflects the changes
import NJWAlgorithm
importlib.reload(NJWAlgorithm)
SpectralClusteringNJW = NJWAlgorithm.SpectralClusteringNJW
import KMeansAlogrithm
importlib.reload(KMeansAlogrithm)
KMeansCustom = KMeansAlogrithm.KMeansCustom


import warnings
warnings.filterwarnings("ignore")

# %%
clusterer = KMeansCustom(n_clusters =4)
clusterer.pipeline_img('images/eagle_30px.png')

# %%
def visualize_line(image_name, values, custom):
    fig, axs = plt.subplots(1, len(values) + 1, figsize=(20, 4))

    clusterer = KMeansCustom(n_clusters =4)
    clusterer.load_image(image_name) 

    axs[0].imshow(clusterer.data, cmap='gray')
    axs[0].set_title('Original')
    axs[0].axis('off')

    for idx, m in enumerate(values):
        clusterer = KMeansCustom(n_clusters = m)
        segmented = clusterer.pipeline_img_line('images/eagle_30px.png')
        # ------------------------------------------------------  custom set boja ----------------------------
        if custom:
            cmap_custom = clusterer.average_color()
            axs[idx + 1].imshow(segmented, cmap=cmap_custom)
        else:
            axs[idx + 1].imshow(segmented, cmap='gray')
        axs[idx + 1].set_title(f'Segmentation (max_cluster={m})')
        axs[idx + 1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
print('custom boje')
visualize_line('images/eagle_30px.png', [2,4,6,8,10], True)
print('random boje')
visualize_line('images/eagle_30px.png', [2,4,6,8,10], False)
# Out:
# custom boje
# random boje

# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

X, y = make_circles(n_samples=500, factor=0.5, noise=0.05)
clusterer = KMeansCustom(n_clusters =2,data=X)
labels=clusterer.pipeline()


plt.figure(figsize=(6, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', edgecolors='k')
plt.title("metoda NJW")
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       4 X, y = make_circles(n_samples=500, factor=0.5, noise=0.05)
# ----> 5 clusterer = KMeansCustom(n_clusters =2,data=X)
#       6 labels=clusterer.pipeline()
#       9 plt.figure(figsize=(6, 6))
#
# NameError: name 'KMeansCustom' is not defined
